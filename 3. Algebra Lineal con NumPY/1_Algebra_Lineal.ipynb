# %%
import numpy as np

# %%
A = np.array([[1, 2], [3, 4]])
B = np.array([[2, 0], [1, 2]])

# %%
# Multiplicacion de matrices

# Primera manera
C = np.dot(A, B)
print(C)

# Segunda manera
D = A @ B
print(D)
# Out:
# [[ 4  4]
#  [10  8]]
# [[ 4  4]
#  [10  8]]
